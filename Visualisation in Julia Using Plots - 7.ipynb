# %%
#Name:-Kuldeep Ghorpade

#ExperimentN No. and Name:- (07) Visualisation in Julia using Plots

# %%
using CSV
using DataFrames
train=CSV.read("loan.csv",DataFrame,normalizenames=true)
# Out:
# 614×13 DataFrame
#  Row │ Loan_ID   Gender    Married   Dependents  Education     Self_Employed   ⋯
#      │ String15  String7?  String3?  String3?    String15      String3?        ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ LP001002  Male      No        0           Graduate      No              ⋯
#    2 │ LP001003  Male      Yes       1           Graduate      No
#    3 │ LP001005  Male      Yes       0           Graduate      Yes
#    4 │ LP001006  Male      Yes       0           Not Graduate  No
#    5 │ LP001008  Male      No        0           Graduate      No              ⋯
#    6 │ LP001011  Male      Yes       2           Graduate      Yes
#    7 │ LP001013  Male      Yes       0           Not Graduate  No
#    8 │ LP001014  Male      Yes       3+          Graduate      No
#    9 │ LP001018  Male      Yes       2           Graduate      No              ⋯
#   10 │ LP001020  Male      Yes       1           Graduate      No
# ...

# %%
size(train)
# Out:
# (614, 13)

# %%
names(train)
# Out:
# 13-element Vector{String}:
#  "Loan_ID"
#  "Gender"
#  "Married"
#  "Dependents"
#  "Education"
#  "Self_Employed"
#  "ApplicantIncome"
#  "CoapplicantIncome"
#  "LoanAmount"
#  "Loan_Amount_Term"
#  "Credit_History"
#  "Property_Area"
#  "Loan_Status"

# %%
train[1:10,1:7]
# Out:
# 10×7 DataFrame
#  Row │ Loan_ID   Gender    Married   Dependents  Education     Self_Employed   ⋯
#      │ String15  String7?  String3?  String3?    String15      String3?        ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ LP001002  Male      No        0           Graduate      No              ⋯
#    2 │ LP001003  Male      Yes       1           Graduate      No
#    3 │ LP001005  Male      Yes       0           Graduate      Yes
#    4 │ LP001006  Male      Yes       0           Not Graduate  No
#    5 │ LP001008  Male      No        0           Graduate      No              ⋯
#    6 │ LP001011  Male      Yes       2           Graduate      Yes
#    7 │ LP001013  Male      Yes       0           Not Graduate  No
#    8 │ LP001014  Male      Yes       3+          Graduate      No
#    9 │ LP001018  Male      Yes       2           Graduate      No              ⋯
#   10 │ LP001020  Male      Yes       1           Graduate      No
# ...

# %%
train[1:10,8:13]
# Out:
# 10×6 DataFrame
#  Row │ CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  Proper ⋯
#      │ Float64            Int64?      Int64?            Int64?          String ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │               0.0     missing               360               1  Urban  ⋯
#    2 │            1508.0         128               360               1  Rural
#    3 │               0.0          66               360               1  Urban
#    4 │            2358.0         120               360               1  Urban
#    5 │               0.0         141               360               1  Urban  ⋯
#    6 │            4196.0         267               360               1  Urban
#    7 │            1516.0          95               360               1  Urban
#    8 │            2504.0         158               360               0  Semiur
#    9 │            1526.0         168               360               1  Urban  ⋯
# ...

# %%
describe(train)
# Out:
# 13×7 DataFrame
#  Row │ variable           mean      min       median  max           nmissing   ⋯
#      │ Symbol             Union…    Any       Union…  Any           Int64      ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Loan_ID                      LP001002          LP002990             0   ⋯
#    2 │ Gender                       Female            Male                13
#    3 │ Married                      No                Yes                  3
#    4 │ Dependents                   0                 3+                  15
#    5 │ Education                    Graduate          Not Graduate         0   ⋯
#    6 │ Self_Employed                No                Yes                 32
#    7 │ ApplicantIncome    5403.46   150       3812.5  81000                0
#    8 │ CoapplicantIncome  1621.25   0.0       1188.5  41667.0              0
#    9 │ LoanAmount         146.412   9         128.0   700                 22   ⋯
# ...

# %%
using Pkg

# %%
Pkg.add("Plots")
# Out:
#     Updating registry at `C:\Users\kulde\.julia\registries\General.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\kulde\.julia\environments\v1.8\Project.toml`
#   No Changes to `C:\Users\kulde\.julia\environments\v1.8\Manifest.toml`

# %%
Pkg.add("PyPlot")
# Out:
#    Resolving package versions...
#    Installed PyPlot ─ v2.11.0
#    Installed PyCall ─ v1.94.1
#     Updating `C:\Users\kulde\.julia\environments\v1.8\Project.toml`
#   [d330b81b] + PyPlot v2.11.0
#     Updating `C:\Users\kulde\.julia\environments\v1.8\Manifest.toml`
#   [438e738f] + PyCall v1.94.1
#   [d330b81b] + PyPlot v2.11.0
#     Building PyCall → `C:\Users\kulde\.julia\scratchspaces\44cfe95a-1eb2-52ea-b672-e2afdf69b78f\53b8b07b721b77144a0fbbbc2675222ebf40a02d\build.log`
# Precompiling project...
#   ✓ PyCall
#   ✓ PyPlot
#   2 dependencies successfully precompiled in 18 seconds. 180 already precompiled.

# %%
Pkg.add("StatsPlots")
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\kulde\.julia\environments\v1.8\Project.toml`
#   No Changes to `C:\Users\kulde\.julia\environments\v1.8\Manifest.toml`

# %%
using Plots
pyplot()
# Out:
# ┌ Info: Installing matplotlib via the Conda matplotlib package...
# └ @ PyCall C:\Users\kulde\.julia\packages\PyCall\ygXW2\src\PyCall.jl:719
# ┌ Info: Running `conda install -y matplotlib` in root environment
# └ @ Conda C:\Users\kulde\.julia\packages\Conda\x2UxR\src\Conda.jl:127
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\kulde\.julia\conda\3
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-1.0.9               |       hcfcfb64_8          19 KB  conda-forge
#     brotli-bin-1.0.9           |       hcfcfb64_8          22 KB  conda-forge
#     contourpy-1.0.6            |  py310h232114e_0         175 KB  conda-forge
#     cryptography-38.0.3        |  py310h52f42fa_0         1.1 MB  conda-forge
# ...

# %%
train=dropmissing(train)
# Out:
# 480×13 DataFrame
#  Row │ Loan_ID   Gender   Married  Dependents  Education     Self_Employed  Ap ⋯
#      │ String15  String7  String3  String3     String15      String3        In ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ LP001003  Male     Yes      1           Graduate      No                ⋯
#    2 │ LP001005  Male     Yes      0           Graduate      Yes
#    3 │ LP001006  Male     Yes      0           Not Graduate  No
#    4 │ LP001008  Male     No       0           Graduate      No
#    5 │ LP001011  Male     Yes      2           Graduate      Yes               ⋯
#    6 │ LP001013  Male     Yes      0           Not Graduate  No
#    7 │ LP001014  Male     Yes      3+          Graduate      No
#    8 │ LP001018  Male     Yes      2           Graduate      No
#    9 │ LP001020  Male     Yes      1           Graduate      No                ⋯
#   10 │ LP001024  Male     Yes      2           Graduate      No
# ...

# %%
Plots.histogram(train[!,"ApplicantIncome"],bins=50,xlabel="ApplicantIncome",labels="frequency")
# Out:
# sys:1: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
using StatsPlots
StatsPlots.boxplot(train[!,"ApplicantIncome"], xlabel="ApplicantIncome")

# %%
StatsPlots.boxplot(train[!,"Education"],train[!,"ApplicantIncome"],labels="Applicantincome")

# %%
Plots.histogram(train[!,"LoanAmount"],bins=50,xlabel="LoanAmount",labels="Frequency")

# %%
using StatsPlots
StatsPlots.boxplot(train[!,"LoanAmount"], ylabel="LoanAmount")

# %%
using StatsPlots
StatsPlots.scatter(train[!,"LoanAmount"], train[!,"ApplicantIncome"],xlabel="LoanAmount")
